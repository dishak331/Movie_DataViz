# %% [markdown]
# # Movies on popular online streaming app Data Visualization

# %%
import math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import plotly.graph_objs as go 
#from plotly.offline import init_notebook_mode,iplot,plot
# %matplotlib inline
#init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
movie = pd.read_csv('movies.csv')
movie.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16145 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
#movie['IMDb'].value_counts().head()
sns.distplot(movie['IMDb'], hist_kws=dict(edgecolor="k", linewidth=2), kde=False, color='red' )
sns.despine()

# %%
movie['Country'].value_counts().head()
# Out:
# United States     8776
# India             1064
# United Kingdom     905
# Canada             555
# Australia          202
# Name: Country, dtype: int64

# %%
movie['Language'].value_counts().head()
# Out:
# English            10955
# Hindi                503
# English,Spanish      276
# Spanish              267
# English,French       174
# Name: Language, dtype: int64

# %%
movie['Genres'].value_counts().head()
#sns.heatmap(x='Genres',data=movie)
# Out:
# Drama           1341
# Documentary     1229
# Comedy          1040
# Comedy,Drama     446
# Horror           436
# Name: Genres, dtype: int64

# %%
movie[movie['Netflix']==1]['Genres'].value_counts().head()
# Out:
# Comedy                  424
# Drama                   259
# Documentary             241
# Comedy,Drama            129
# Comedy,Drama,Romance    100
# Name: Genres, dtype: int64

# %%
movie[movie['Prime Video']==1]['Genres'].value_counts().head()
# Out:
# Drama           1069
# Documentary      900
# Comedy           622
# Horror           400
# Comedy,Drama     302
# Name: Genres, dtype: int64

# %%
movie[movie['Disney+']==1]['Genres'].value_counts().head()
# Out:
# Documentary                                  34
# Animation,Adventure,Comedy,Family,Fantasy    16
# Action,Adventure,Sci-Fi                      13
# Comedy,Family                                13
# Comedy,Drama,Family                          13
# Name: Genres, dtype: int64

# %%
movie[movie['Hulu']==1]['Genres'].value_counts().head()
# Out:
# Documentary      75
# Drama            44
# Comedy,Drama     38
# Comedy           36
# Drama,Romance    30
# Name: Genres, dtype: int64

# %%
sns.distplot(movie['Runtime'], hist_kws=dict(edgecolor="k", linewidth=2), kde=False, color='#f98d3f')
sns.despine()

# %%
def func(x):
    if x==1:
        return x
def func2(x):
    s=x[0:len(x)-1]
    return int(s)
movie['Netflix']=movie['Netflix'].apply(lambda x:func(x))
movie['Hulu']=movie['Hulu'].apply(lambda x:func(x))
movie['Prime Video']=movie['Prime Video'].apply(lambda x:func(x))
movie['Disney+']=movie['Disney+'].apply(lambda x:func(x))
movie['c1']=movie['Age'].isnull()
movie['c2']=movie['Rotten Tomatoes'].isnull()
#movie['c1'][1].dtype
#movie['c1'==False]['Age']
movie['age']=movie[movie['c1']==False]['Age'].apply(lambda x: x[0:len(x)-1])
movie['Rotten tomatoes']=movie[movie['c2']==False]['Rotten Tomatoes'].apply(lambda x: func2(x))
#movie.head()
#sns.barplot(x='age',y='IMDb',data=movie)

# %%
fig, axes = plt.subplots(ncols=4, figsize=(20,5))
sns.violinplot(x='Netflix',y='Runtime',data=movie, palette='OrRd',ax=axes[0])
sns.violinplot(x='Hulu',y='Runtime',data=movie, palette='OrRd', ax=axes[1])
sns.violinplot(x='Prime Video',y='Runtime',data=movie, palette='OrRd', ax=axes[2])
sns.violinplot(x='Disney+',y='Runtime',data=movie, palette='OrRd',ax=axes[3])

# %%
fig, axes = plt.subplots(ncols=4, figsize=(20,5))
sns.boxplot(x='Netflix',y='IMDb',data=movie, palette='Pastel1',ax=axes[0])
sns.boxplot(x='Hulu',y='IMDb',data=movie, palette='Pastel1',ax=axes[1])
sns.boxplot(x='Prime Video',y='IMDb',data=movie, palette='Pastel1',ax=axes[2])
sns.boxplot(x='Disney+',y='IMDb',data=movie,palette='Pastel1', ax=axes[3])

# %%
fig, axes = plt.subplots(ncols=4, figsize=(20,5))
sns.boxplot(x='Netflix',y='Year',data=movie, palette='Set2', ax=axes[0])
sns.boxplot(x='Hulu',y='Year',data=movie, palette='Set2',ax=axes[1])
sns.boxplot(x='Prime Video',y='Year',data=movie,palette='Set2', ax=axes[2])
sns.boxplot(x='Disney+',y='Year',data=movie,palette='Set2', ax=axes[3])

# %%
sns.jointplot(x='Year',y='IMDb',data=movie,color='#c498d9')

# %%
sns.barplot(x='age',y='IMDb',data=movie, palette='winter')
sns.despine()

# %%
sns.barplot(x='age',y='Rotten tomatoes',data=movie, palette='YlGnBu')
sns.despine()

# %%
sns.jointplot(x='Year',y='Rotten tomatoes',data=movie, color='#8fc7bb')

# %%
sns.jointplot(x='IMDb',y='Rotten tomatoes',data=movie, color='#a4bf93')

# %%
sns.distplot(movie['Rotten tomatoes'],hist_kws=dict(edgecolor="k", linewidth=2), kde=False,color='orange')
sns.despine()

# %%
sns.jointplot(x='Runtime',y='IMDb',data=movie,color='#b89ab7')

# %%
sns.jointplot(x='Runtime',y='Rotten tomatoes',data=movie, color='#c2849d')

# %%
sns.countplot(x='age',data=movie, palette='Pastel2')
sns.despine()

# %%
fig, axes = plt.subplots(ncols=4, figsize=(20,5))
sns.boxplot(x='Netflix',y='Rotten tomatoes',data=movie,palette='Set1', ax=axes[0])
sns.boxplot(x='Hulu',y='Rotten tomatoes',data=movie,palette='Set1', ax=axes[1])
sns.boxplot(x='Prime Video',y='Rotten tomatoes',data=movie, palette='Set1',ax=axes[2])
sns.boxplot(x='Disney+',y='Rotten tomatoes',data=movie, palette='Set1',ax=axes[3])

# %%
max(movie['IMDb'])
# Out:
# 9.3

# %%
movie[movie['IMDb']==9.3]['Title']
# Out:
# 1292    My Next Guest with David Letterman and Shah Ru...
# 5110                                      Love on a Leash
# 6566                                           Square One
# 6837              Steven Banks: Home Entertainment Center
# 7220                                   Down, But Not Out!
# 7426                                               Bounty
# Name: Title, dtype: object

# %%
movie[movie['Rotten tomatoes']==100]['Title'].count()
# Out:
# 407
